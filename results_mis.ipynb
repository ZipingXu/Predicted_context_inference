# %%
import importlib
import visualization
importlib.reload(visualization)
from visualization import *
import os

# %%
with open('runs/history_dict_random_0.1_0.5_mis_False.pkl', 'rb') as f:
    history_dict, args = pickle.load(f)
# random environment
    # print("true theta \n", args.theta) if not args.mis else print("true theta \n", args.best_theta)
    print("weighted theta est \n", np.mean(history_dict['theta_est']['Random'], axis=0)[:, 1, :])
    print("var est \n", np.mean(history_dict['var_est_list']['Random'], axis=0)[-1])
    print("coverage \n", np.mean(history_dict['coverage_list']['Random'], axis=0)[-1])
    print("weighted theta std \n", np.std(history_dict['theta_est']['Random'], axis=0)[:, 1, :]**2)
    plot_coverage_w_ax(history_dict, args, alpha=0.9)
# Out:
# weighted theta est
#  [[-0.93245769]
#  [-0.40932975]]
# var est
#  0.1679977146454422
# coverage
#  0.8833333333333333
# weighted theta std
#  [[2.0208454 ]
#  [0.19643038]]

# %%
# test the effects of -l
mis_list = [True, False]
env_list = ['failure1', 'failure2', 'random_0.1_0.5', 'polynomial', 'neural_network']

# Create a 3x3 grid of subplots
fig, axes = plt.subplots(3, 3, figsize=(15, 12))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Counter for subplot position
plot_idx = 0

for env in env_list:
    for mis in mis_list:
        name = f'runs/mis/history_dict_{env}_mis_{mis}.pkl'
        print(name)
        if not os.path.exists(name):
            continue
        with open(name, 'rb') as f:
            history_dict, args = pickle.load(f)
        # Get the current subplot
        ax = axes[plot_idx]
        
        # Pass the axis to plot_coverage
        plot_coverage_w_ax(history_dict, args, ax=ax,alpha=0.9)
        
        # Add title to each subplot
        ax.set_title(f'Environment: {env}, mis: {mis}')
        
        # Increment plot index
        plot_idx += 1

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# runs/mis/history_dict_failure1_mis_True.pkl
# runs/mis/history_dict_failure1_mis_False.pkl
# runs/mis/history_dict_failure2_mis_True.pkl
# runs/mis/history_dict_failure2_mis_False.pkl
# runs/mis/history_dict_random_0.1_0.5_mis_True.pkl
# runs/mis/history_dict_random_0.1_0.5_mis_False.pkl
# runs/mis/history_dict_polynomial_mis_True.pkl
# runs/mis/history_dict_polynomial_mis_False.pkl
# runs/mis/history_dict_neural_network_mis_True.pkl
# runs/mis/history_dict_neural_network_mis_False.pkl

# %%
# test the effects of -l
mis_list = [True, False]
env_list = ['failure1', 'failure2', 'random_0.1_0', 'polynomial', 'neural_network']

# Create a 3x3 grid of subplots
fig, axes = plt.subplots(3, 3, figsize=(15, 12))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Counter for subplot position
plot_idx = 0

for env in env_list:
    for mis in mis_list:
        name = f'runs/mis/history_dict_{env}_mis_{mis}.pkl'
        print(name)
        if not os.path.exists(name):
            continue
        with open(name, 'rb') as f:
            history_dict, args = pickle.load(f)
        # Get the current subplot
        ax = axes[plot_idx]
        
        # Pass the axis to plot_coverage
        plot_coverage_w_ax(history_dict, args, ax=ax)
        
        # Add title to each subplot
        ax.set_title(f'Environment: {env}, mis: {mis}')
        
        # Increment plot index
        plot_idx += 1

# Adjust layout
plt.tight_layout()
plt.show()

# %%
with open('runs/mis/history_dict_failure2_mis_False.pkl', 'rb') as f:
    history_dict, args = pickle.load(f)

# %%
history_dict.keys()
# Out:
# dict_keys(['theta_est', 'pi_list', 'theta_est_batch', 'theta_est_naive', 'coverage_list', 'policy_func', 'avg_pa_list', 'var_est_list'])

# %%
np.mean(history_dict['var_est_list']['MEB'], axis=0)
# Out:
# array([0., 0.])

# %%
print(np.mean(history_dict['theta_est_batch']['MEB'], axis=0))
print(np.mean(history_dict['theta_est_naive']['MEB'], axis=0))
# Out:
# [[0.]
#  [0.]]
# [[0.]
#  [0.]]

# %%
with open('runs/history_dict_failure1_test.pkl', 'rb') as f:
    history_dict, args = pickle.load(f)

# %%
with open('runs/history_dict_failure1_test.pkl', 'rb') as f:
    history_dict, args = pickle.load(f)
# random environment
print(np.mean(history_dict['theta_est_batch']['UCB'], axis=0))
print(np.mean(history_dict['theta_est']['UCB'], axis=0)[:, 1, :])
print(np.mean(history_dict['var_est_list']['UCB'], axis=0))
print(np.mean(history_dict['coverage_list']['UCB'], axis=0))
print(np.std(history_dict['theta_est']['UCB'], axis=0)[:, 1, :]**2)
# Out:
# [[3.04232376]
#  [1.00107391]]
# [[0.29118564]
#  [0.289997  ]]
# [0.       0.215903]
# [0.   0.98]
# [[6.04823697e-05]
#  [5.84473019e-05]]

# %%
with open('runs/history_dict_random_0.1_0.1_test.pkl', 'rb') as f:
    history_dict, args = pickle.load(f)
# random environment
print(np.mean(history_dict['theta_est_batch']['Random'], axis=0))
print(np.mean(history_dict['theta_est']['Random'], axis=0)[:, 1, :])
print(np.mean(history_dict['var_est_list']['Random'], axis=0))
print(np.mean(history_dict['coverage_list']['Random'], axis=0))
print(np.std(history_dict['theta_est']['Random'], axis=0)[:, 1, :]**2)
# Out:
# [[0.03906705]
#  [0.00588933]]
# [[0.03933093]
#  [0.00620309]]
# [0.         0.00184583]
# [0.         0.94333333]
# [[1.0645457]
#  [0.911003 ]]

# %%
with open('runs/history_dict_random_0.1_0.1_test.pkl', 'rb') as f:
    history_dict, args = pickle.load(f)
# random environment
print(np.mean(history_dict['theta_est_batch']['Random'], axis=0))
print(np.mean(history_dict['theta_est']['Random'], axis=0)[:, 1, :])
print(np.mean(history_dict['var_est_list']['Random'], axis=0))
print(np.mean(history_dict['coverage_list']['Random'], axis=0))
print(np.std(history_dict['theta_est']['Random'], axis=0)[:, 1, :]**2)
# Out:
# [[ 0.1073407 ]
#  [-0.14835491]]
# [[ 0.10672612]
#  [-0.14749093]]
# [0.        0.0016443]
# [0.         0.93333333]
# [[0.93260341]
#  [1.09600825]]

# %%
print(np.mean(history_dict['theta_est_batch']['Random'], axis=0))
print(np.mean(history_dict['theta_est']['Random'], axis=0)[:, 1, :])
print(np.mean(history_dict['var_est_list']['Random'], axis=0))
print(np.mean(history_dict['coverage_list']['Random'], axis=0))
print(np.std(history_dict['theta_est']['Random'], axis=0)[:, 1, :]**2)
# Out:
# [[2.99723823]
#  [1.00567898]]
# [[2.9938026]
#  [1.00453  ]]
# [0.         0.08273269]
# [0. 1.]
# [[0.02311542]
#  [0.00262907]]

# %%
print(np.mean(history_dict['theta_est_batch']['MEB'], axis=0))
print(np.mean(history_dict['theta_est']['MEB'], axis=0)[:, 1, :])
print(np.mean(history_dict['var_est_list']['MEB'], axis=0))
np.mean(history_dict['coverage_list']['MEB'], axis=0)
# Out:
# [[0.]
#  [0.]]
# [[0.]
#  [0.]]
# [0. 0.]
# array([0., 0.])

# %%
np.std(history_dict['theta_est']['MEB'], axis=0)[:, 1, :] #0.07584516
# Out:
# array([[0.27541679],
#        [0.06832795]])

# %%
with open('runs/history_dict_failure1_.pkl', 'rb') as f:
    history_dict, args = pickle.load(f)

# %%
plot_coverage_w_ax(history_dict, args)

# %%
# print(np.mean(history_dict['theta_est']['UCB'], axis=0))
print(np.mean(history_dict['coverage_list']['Random'], axis=0))
print(np.mean(history_dict['coverage_list']['MEB'], axis=0))
print(np.mean(history_dict['coverage_list']['Boltzmann'], axis=0))
# Out:
# [0.    0.998]
# [0.   0.95]
# [0. 1.]

# %%
# print(np.mean(history_dict['theta_est']['UCB'], axis=0))
print(np.mean(history_dict['theta_est_batch']['Random'], axis=0))
print(np.mean(history_dict['theta_est_batch']['MEB'], axis=0))
print(np.mean(history_dict['theta_est_batch']['Boltzmann'], axis=0))
# Out:
# [[0.62672275]
#  [0.2086889 ]]
# [[0.59563567]
#  [0.21163742]]
# [[0.62424265]
#  [0.20950227]]

# %%
# print(np.mean(history_dict['theta_est']['UCB'], axis=0))
print(np.mean(history_dict['var_est_list']['Random'], axis=0))
print(np.mean(history_dict['var_est_list']['MEB'], axis=0))
print(np.mean(history_dict['var_est_list']['Boltzmann'], axis=0))
# Out:
# [0.         0.19634743]
# [0.00000000e+00 7.13543613e+12]
# [0.       0.195405]

# %%
# print(np.mean(history_dict['theta_est']['UCB'], axis=0))
print(np.mean(history_dict['theta_est_batch']['Random'], axis=0))
print(np.mean(history_dict['theta_est_batch']['MEB'], axis=0))
print(np.mean(history_dict['theta_est']['MEB'], axis=0)[:, 1, :])
print(np.mean(history_dict['theta_est']['UCB'], axis=0)[:, 1, :])
# Out:
# [[0.62672275]
#  [0.2086889 ]]
# [[0.59563567]
#  [0.21163742]]
# [[8.11467127e+12]
#  [8.95825364e+00]]
# [[0.29518346]
#  [0.29374178]]

# %%
print(np.mean(history_dict['var_est_list']['MEB'], axis=0))
# Out:
# [0.00000000e+00 7.13543613e+12]

# %%
print(np.mean(history_dict['coverage_list']['MEB'], axis=0))
# Out:
# [0.   0.95]

# %%
args
# Out:
# Namespace(T=501, p0=0.1, env='failure1', gamma=0, C=1.0, l=1.0, rho=1.0, d=1, sigma_eta=0, context_noise='Gaussian', sigma_e=0, sigma_s=0.1, n_action=2, coverage_freq=500, n_rep=500, seed=42, save_path='./runs/', name='', mis=True, pi_nd=array([0.5, 0.5]), theta_all=[array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]), array([[3, 1]]),
# ...

# %%
with open('runs/history_dict_neural_network_test.pkl', 'rb') as f:
    history_dict, args = pickle.load(f)
# random environment
print(np.mean(history_dict['theta_est_batch']['Random'], axis=0))
print(np.mean(history_dict['theta_est']['Random'], axis=0)[:, 1, :])
print(np.mean(history_dict['var_est_list']['Random'], axis=0))
print(np.mean(history_dict['coverage_list']['Random'], axis=0))
print(np.std(history_dict['theta_est']['Random'], axis=0)[:, 1, :]**2)
# Out:
# [[ 0.02160172]
#  [-0.03307148]]
# [[ 0.0211552 ]
#  [-0.03384837]]
# [0.         0.00015875]
# [0.   0.81]
# [[0.09074921]
#  [0.07244485]]

# %%
with open('runs/history_dict_polynomial_test.pkl', 'rb') as f:
    history_dict, args = pickle.load(f)
# random environment
print(np.mean(history_dict['theta_est_batch']['Random'], axis=0))
print(np.mean(history_dict['theta_est']['Random'], axis=0)[:, 1, :])
print(np.mean(history_dict['var_est_list']['Random'], axis=0))
print(np.mean(history_dict['coverage_list']['Random'], axis=0))
print(np.std(history_dict['theta_est']['Random'], axis=0)[:, 1, :]**2)
# Out:
# [[0.04914253]
#  [0.21315381]]
# [[0.0463617 ]
#  [0.21069637]]
# [0.         0.00075475]
# [0.   0.74]
# [[1.14101148]
#  [1.21615239]]

# %%
with open('runs/history_dict_failure1_test.pkl', 'rb') as f:
    history_dict, args = pickle.load(f)
# random environment
print(np.mean(history_dict['theta_est_batch']['Random'], axis=0))
print(np.mean(history_dict['theta_est']['Random'], axis=0)[:, 1, :])
print(np.mean(history_dict['var_est_list']['Random'], axis=0))
print(np.mean(history_dict['coverage_list']['Random'], axis=0))
print(np.std(history_dict['theta_est']['Random'], axis=0)[:, 1, :]**2)
# Out:
# [[2.99310667]
#  [0.99978679]]
# [[2.99134052]
#  [0.99903631]]
# [0.         0.05213748]
# [0. 1.]
# [[0.01124819]
#  [0.00136785]]
